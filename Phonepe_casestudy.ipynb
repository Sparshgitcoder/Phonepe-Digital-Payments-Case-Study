# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
#you can see the outputs of multiple expressions in a single cell, 
#making it easier to inspect the data.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Task 1.

# %% [markdown]
# ## 1.1 Load each dataset and display its structure

# %%
stu = pd.read_excel('phonepe_raw_data.xlsx',sheet_name ='State_Txn and Users' )

# %%
stu.head()
# Out:
#                        State  Year  Quarter  Transactions  Amount (INR)  \
# 0  Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1  Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2  Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3  Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4  Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
#
#      ATV (INR)  Registered Users  App Opens
# 0  2197.621091              6740          0
# 1  2498.989022              9405          0
# 2  3415.768284             12149          0
# 3  3811.277720             15222          0
# 4  3355.630147             18596          0

# %%
sts = pd.read_excel('phonepe_raw_data.xlsx',sheet_name ='State_TxnSplit' )

# %%
sts.tail(10)
# Out:
#             State  Year  Quarter          Transaction Type  Transactions  \
# 2504  West Bengal  2021        1     Peer-to-peer payments      53869075
# 2505  West Bengal  2021        1         Merchant payments      37143701
# 2506  West Bengal  2021        1  Recharge & bill payments      26673733
# 2507  West Bengal  2021        1        Financial Services        166727
# 2508  West Bengal  2021        1                    Others        400816
# 2509  West Bengal  2021        2     Peer-to-peer payments      64661051
# 2510  West Bengal  2021        2         Merchant payments      41696787
# 2511  West Bengal  2021        2  Recharge & bill payments      34799709
# 2512  West Bengal  2021        2        Financial Services        190537
# 2513  West Bengal  2021        2                    Others        549353
#
#       Amount (INR)    ATV (INR)
# 2504  2.022402e+11  3754.292226
# 2505  2.891834e+10   778.553104
# 2506  1.133967e+10   425.124820
# 2507  1.754458e+08  1052.293941
# ...

# %%
sdd = pd.read_excel('phonepe_raw_data.xlsx',sheet_name ='State_DeviceData' )
mid = int(len(sdd)/2)

sdd.iloc[mid:mid+11,:]
# Out:
#             State  Year  Quarter    Brand  Registered Users  Percentage
# 2772  Lakshadweep  2018        1  Samsung               102    0.203593
# 2773  Lakshadweep  2018        1   Xiaomi               100    0.199601
# 2774  Lakshadweep  2018        1     Vivo                67    0.133733
# 2775  Lakshadweep  2018        1     Oppo                56    0.111776
# 2776  Lakshadweep  2018        1   Huawei                25    0.049900
# 2777  Lakshadweep  2018        1  OnePlus                22    0.043912
# 2778  Lakshadweep  2018        1    Apple                20    0.039920
# 2779  Lakshadweep  2018        1   Realme                20    0.039920
# 2780  Lakshadweep  2018        1   Gionee                12    0.023952
# 2781  Lakshadweep  2018        1  COOLPAD                10    0.019960
# 2782  Lakshadweep  2018        1   Others                67    0.133733

# %%
# display first 10 and last 10 rows
dtu = pd.read_excel('phonepe_raw_data.xlsx',sheet_name ='District_Txn and Users')
pd.concat([dtu.head(10),dtu.tail(10)])
# Out:
#                            State  Year  Quarter                    District  \
# 0      Andaman & Nicobar Islands  2018        1                    Nicobars
# 1      Andaman & Nicobar Islands  2018        1    North And Middle Andaman
# 2      Andaman & Nicobar Islands  2018        1               South Andaman
# 3      Andaman & Nicobar Islands  2018        2                    Nicobars
# 4      Andaman & Nicobar Islands  2018        2    North And Middle Andaman
# 5      Andaman & Nicobar Islands  2018        2               South Andaman
# 6      Andaman & Nicobar Islands  2018        3                    Nicobars
# 7      Andaman & Nicobar Islands  2018        3    North And Middle Andaman
# 8      Andaman & Nicobar Islands  2018        3               South Andaman
# 9      Andaman & Nicobar Islands  2018        4                    Nicobars
# 10238                West Bengal  2021        2                 Murshidabad
# ...

# %%
dd = pd.read_excel('phonepe_raw_data.xlsx',sheet_name ='District Demographics')
len(dd)
# Out:
# 742

# %%
# display every 10th row.
dd.iloc[list(range(9,len(dd),10)),:]
#or
dd.iloc[::10,:]
# Out:
#                          State       District     Headquarters  Population  \
# 9               Andhra Pradesh     Srikakulam       Srikakulam     2699471
# 19           Arunachal Pradesh   Kurung Kumey        Koloriang       89717
# 29           Arunachal Pradesh       Shi Yomi             Tato       13310
# 39                       Assam         Bajali         Pathsala      253816
# 49                       Assam      Dibrugarh        Dibrugarh     1327748
# ..                         ...            ...              ...         ...
# 699  Andaman & Nicobar Islands  South Andaman       Port Blair      238142
# 709            Jammu & Kashmir      Ganderbal        Ganderbal      297003
# 719            Jammu & Kashmir          Reasi            Reasi      314714
# 729                      Delhi      New Delhi  Connaught Place      142004
# 739                 Puducherry           Mahé             Mahé       41816
#
#      Area (sq km)  Density  Code Alternate Name
# ...

# %% [markdown]
# # 1.2 Display basic statistics and data tyoes for each dataset

# %%
#1. For each dataset, display the summary statictics (mean, median, etc) for numerical columns.

# %%
stu
stu.describe()
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens
# ...

# %%
sts
sts.describe()
# Out:
#                           State  Year  Quarter          Transaction Type  \
# 0     Andaman & Nicobar Islands  2018        1  Recharge & bill payments
# 1     Andaman & Nicobar Islands  2018        1     Peer-to-peer payments
# 2     Andaman & Nicobar Islands  2018        1         Merchant payments
# 3     Andaman & Nicobar Islands  2018        1        Financial Services
# 4     Andaman & Nicobar Islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 2509                West Bengal  2021        2     Peer-to-peer payments
# 2510                West Bengal  2021        2         Merchant payments
# 2511                West Bengal  2021        2  Recharge & bill payments
# 2512                West Bengal  2021        2        Financial Services
# 2513                West Bengal  2021        2                    Others
#
#       Transactions  Amount (INR)    ATV (INR)
# ...

# %%
sdd
sdd.describe(include='all')
# Out:
#                           State  Year  Quarter    Brand  Registered Users  \
# 0     Andaman & Nicobar Islands  2018        1   Xiaomi              1665
# 1     Andaman & Nicobar Islands  2018        1  Samsung              1445
# 2     Andaman & Nicobar Islands  2018        1     Vivo               982
# 3     Andaman & Nicobar Islands  2018        1     Oppo               501
# 4     Andaman & Nicobar Islands  2018        1  OnePlus               332
# ...                         ...   ...      ...      ...               ...
# 5539                West Bengal  2021        2   Lenovo            350841
# 5540                West Bengal  2021        2     Asus            297579
# 5541                West Bengal  2021        2   Huawei            272965
# 5542                West Bengal  2021        2    Apple            201393
# 5543                West Bengal  2021        2   Others           1928653
#
#       Percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# ...

# %%
dtu
dtu.describe()
# Out:
#                            State  Year  Quarter                    District  \
# 0      Andaman & Nicobar Islands  2018        1                    Nicobars
# 1      Andaman & Nicobar Islands  2018        1    North And Middle Andaman
# 2      Andaman & Nicobar Islands  2018        1               South Andaman
# 3      Andaman & Nicobar Islands  2018        2                    Nicobars
# 4      Andaman & Nicobar Islands  2018        2    North And Middle Andaman
# ...                          ...   ...      ...                         ...
# 10243                West Bengal  2021        2             Purba Bardhaman
# 10244                West Bengal  2021        2             Purba Medinipur
# 10245                West Bengal  2021        2                     Purulia
# 10246                West Bengal  2021        2  South Twenty Four Parganas
# 10247                West Bengal  2021        2              Uttar Dinajpur
#
# ...

# %%
dd
dd.describe()
# Out:
#               State       District    Headquarters  Population  Area (sq km)  \
# 0    Andhra Pradesh      Anantapur       Anantapur     4083315       19130.0
# 1    Andhra Pradesh       Chittoor        Chittoor     4170468       15152.0
# 2    Andhra Pradesh  East Godavari        Kakinada     5151549       10807.0
# 3    Andhra Pradesh         Guntur          Guntur     4889230       11391.0
# 4    Andhra Pradesh            YSR          Kadapa     2884524       15359.0
# ..              ...            ...             ...         ...           ...
# 737           Delhi     West Delhi  Rajouri Garden     2543243         112.0
# 738      Puducherry       Karaikal        Karaikal      200222         157.0
# 739      Puducherry           Mahé            Mahé       41816           9.0
# 740      Puducherry     Puducherry     Pondicherry      950289         293.0
# 741      Puducherry          Yanam           Yanam       55626          30.0
#
#      Density  Code Alternate Name
# ...

# %%
#2. Display the data types of each column in each dataset

# %%
stu.dtypes
# Out:
# State                object
# Year                  int64
# Quarter               int64
# Transactions          int64
# Amount (INR)        float64
# ATV (INR)           float64
# Registered Users      int64
# App Opens             int64
# dtype: object

# %%
sts.dtypes
# Out:
# State                object
# Year                  int64
# Quarter               int64
# Transaction Type     object
# Transactions          int64
# Amount (INR)        float64
# ATV (INR)           float64
# dtype: object

# %%
sdd.dtypes
# Out:
# State                object
# Year                  int64
# Quarter               int64
# Brand                object
# Registered Users      int64
# Percentage          float64
# dtype: object

# %%
dtu.dtypes
# Out:
# State                object
# Year                  int64
# Quarter               int64
# District             object
# Code                 object
# Transactions          int64
# Amount (INR)        float64
# ATV (INR)           float64
# Registered Users      int64
# App Opens             int64
# dtype: object

# %%
dd.dtypes
# Out:
# State              object
# District           object
# Headquarters       object
# Population          int64
# Area (sq km)      float64
# Density             int64
# Code               object
# Alternate Name     object
# dtype: object

# %% [markdown]
# # 1.3 Check for missing values

# %%
#1 identify any missing values in each dataset

# %%
stu['State'].value_counts()
# Out:
# State
# Andaman & Nicobar Islands               14
# Andhra Pradesh                          14
# Maharashtra                             14
# Manipur                                 14
# Meghalaya                               14
# Mizoram                                 14
# Nagaland                                14
# Odisha                                  14
# Puducherry                              14
# Punjab                                  14
# Rajasthan                               14
# Sikkim                                  14
# Tamil Nadu                              14
# Telangana                               14
# Tripura                                 14
# Uttarakhand                             14
# Uttar Pradesh                           14
# Madhya Pradesh                          14
# Lakshadweep                             14
# Ladakh                                  14
# Delhi                                   14
# Arunachal Pradesh                       14
# ...

# %%
stu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             504 non-null    object
#  1   Year              504 non-null    int64
#  2   Quarter           504 non-null    int64
#  3   Transactions      504 non-null    int64
#  4   Amount (INR)      503 non-null    float64
#  5   ATV (INR)         504 non-null    float64
#  6   Registered Users  504 non-null    int64
#  7   App Opens         504 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 31.6+ KB

# %%
sts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2514 entries, 0 to 2513
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             2514 non-null   object
#  1   Year              2514 non-null   int64
#  2   Quarter           2514 non-null   int64
#  3   Transaction Type  2514 non-null   object
#  4   Transactions      2514 non-null   int64
#  5   Amount (INR)      2514 non-null   float64
#  6   ATV (INR)         2514 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 137.6+ KB

# %%
sdd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5544 entries, 0 to 5543
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             5544 non-null   object
#  1   Year              5544 non-null   int64
#  2   Quarter           5544 non-null   int64
#  3   Brand             5544 non-null   object
#  4   Registered Users  5544 non-null   int64
#  5   Percentage        5544 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 260.0+ KB

# %%
dtu.info() #-> code column having 28 null entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10248 entries, 0 to 10247
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             10248 non-null  object
#  1   Year              10248 non-null  int64
#  2   Quarter           10248 non-null  int64
#  3   District          10248 non-null  object
#  4   Code              10220 non-null  object
#  5   Transactions      10248 non-null  int64
#  6   Amount (INR)      10248 non-null  float64
#  7   ATV (INR)         10244 non-null  float64
#  8   Registered Users  10248 non-null  int64
#  9   App Opens         10248 non-null  int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 800.8+ KB

# %%
dtu['Code'].isnull().sum()
# Out:
# 28

# %%
dtu['Code'].notnull().sum()
# Out:
# 10220

# %%
(dtu['Code'].isnull().sum() *100)/dtu['Code'].notnull().sum()
# Out:
# 0.273972602739726

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           742 non-null    object
#  1   District        742 non-null    object
#  2   Headquarters    742 non-null    object
#  3   Population      742 non-null    int64
#  4   Area (sq km)    742 non-null    float64
#  5   Density         742 non-null    int64
#  6   Code            742 non-null    object
#  7   Alternate Name  742 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 46.5+ KB

# %%
#3. Highlight which column has highest percentage of missing values in each dataset

# %%
#->dtu['code']

# %% [markdown]
# ## 1.4 Create a summary

# %%
#1. Calculate the total number of states and total number of districts.

# %%
dd.head()
# Out:
#             State       District Headquarters  Population  Area (sq km)  \
# 0  Andhra Pradesh      Anantapur    Anantapur     4083315       19130.0
# 1  Andhra Pradesh       Chittoor     Chittoor     4170468       15152.0
# 2  Andhra Pradesh  East Godavari     Kakinada     5151549       10807.0
# 3  Andhra Pradesh         Guntur       Guntur     4889230       11391.0
# 4  Andhra Pradesh            YSR       Kadapa     2884524       15359.0
#
#    Density  Code Alternate Name
# 0      213  AP01      Anantapur
# 1      275  AP02       Chittoor
# 2      477  AP03  East Godavari
# 3      429  AP04         Guntur
# 4      188  AP13            YSR

# %%
dd['State'].unique()
dd['State'].nunique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal', 'Andaman & Nicobar Islands', 'Chandigarh',
#        'Dadra & Nagar Haveli and Daman & Diu', 'Jammu & Kashmir',
#        'Ladakh', 'Lakshadweep', 'Delhi', 'Puducherry'], dtype=object)
# 36

# %%
dd['District'].unique()
# Out:
# array(['Anantapur', 'Chittoor', 'East Godavari', 'Guntur', 'YSR',
#        'Krishna', 'Kurnool', 'Prakasam', 'Sri Potti Sriramulu Nellore',
#        'Srikakulam', 'Visakhapatnam', 'Vizianagaram', 'West Godavari',
#        'Anjaw', 'Changlang', 'East Kameng', 'East Siang', 'Kamle',
#        'Kra Daadi', 'Kurung Kumey', 'Lepa Rada', 'Lohit', 'Longding',
#        'Lower Dibang Valley', 'Lower Siang', 'Lower Subansiri', 'Namsai',
#        'Pakke-Kessang', 'Papum Pare', 'Shi Yomi', 'Siang', 'Tawang',
#        'Tirap', 'Upper Dibang Valley', 'Upper Siang', 'Upper Subansiri',
#        'West Kameng', 'West Siang', 'Baksa', 'Bajali', 'Barpeta',
#        'Bishwanath', 'Bongaigaon', 'Cachar', 'Charaideo', 'Chirang',
#        'Darrang', 'Dhemaji', 'Dhubri', 'Dibrugarh', 'Dima Hasao',
#        'Goalpara', 'Golaghat', 'Hailakandi', 'Hojai', 'Jorhat', 'Kamrup',
#        'Kamrup Metropolitan', 'Karbi Anglong', 'Karimganj', 'Kokrajhar',
# ...

# %%
dd['District'].nunique()
# Out:
# 736

# %%
#2. identify the state with highest number of districts

# %%
dd['State'].value_counts().idxmax()
# Out:
# 'Uttar Pradesh'

# %%
######################### TASK 2 ###############################

# %% [markdown]
# ## 2.1 Analyze transaction trends over the years for each state

# %% [markdown]
# ## 2.2.1. Calculate the total number of transactons and total transaction amount for each state over the years. Display the results in a tabular format.

# %%
stu.sample(10)
# Out:
#                 State  Year  Quarter  Transactions  Amount (INR)    ATV (INR)  \
# 168  Himachal Pradesh  2018        1        481918  6.287378e+08  1304.657237
# 279    Madhya Pradesh  2021        2     223314680  4.255008e+11  1905.386462
# 164           Haryana  2020        3      57938179  1.095680e+11  1891.118298
# 92       Chhattisgarh  2020        1      19523991  3.286060e+10  1683.088139
# 481     Uttar Pradesh  2019        2      58883500  9.891752e+10  1679.885186
# 436         Telangana  2018        3      19332703  3.203009e+10  1656.782976
# 55              Assam  2021        2      25432905  5.919247e+10  2327.397259
# 490       West Bengal  2018        1      11710225  1.062598e+10   907.410281
# 429        Tamil Nadu  2020        2      51870110  9.582651e+10  1847.432151
# 339          Nagaland  2018        4        139333  3.880135e+08  2784.792314
#
#      Registered Users  App Opens
# 168            227373          0
# 279          15940935  727741649
# ...

# %%
result = stu.groupby(['State', 'Year']).agg(
    No_of_Transactions=('Transactions', 'sum'),
    Transaction_Amount=('Amount (INR)', 'sum')
).reset_index()

# %%
result
# Out:
#                          State  Year  No_of_Transactions  Transaction_Amount
# 0    Andaman & Nicobar Islands  2018               58021        1.890761e+08
# 1    Andaman & Nicobar Islands  2019              133104        4.734648e+08
# 2    Andaman & Nicobar Islands  2020              446274        1.296423e+09
# 3    Andaman & Nicobar Islands  2021              586166        1.682854e+09
# 4               Andhra Pradesh  2018            77779112        1.220720e+11
# ..                         ...   ...                 ...                 ...
# 139                Uttarakhand  2021            44608834        7.727901e+10
# 140                West Bengal  2018           120011635        1.115887e+11
# 141                West Bengal  2019           257900590        2.660145e+11
# 142                West Bengal  2020           304222327        5.527316e+11
# 143                West Bengal  2021           260151489        5.223720e+11
#
# [144 rows x 4 columns]

# %%
'''2 Identify the top 5 states with the highest transaction volume
and the top 5 states with the lowest tarnsaction volumes. 
Display the results.'''

# %%
result = stu.groupby(['State']).agg(
    No_of_Transactions=('Transactions', 'sum'),
    Transaction_Amount=('Amount (INR)', 'sum')
).reset_index()
result = result.sort_values('Transaction_Amount', ascending=False )
list(result.iloc[0:5,0])
# Out:
# ['Telangana', 'Karnataka', 'Maharashtra', 'Andhra Pradesh', 'Rajasthan']

# %%
#the top 5 states with the highest transaction volume are 
#Telangana, Karnataka, Maharashtra, Andhra Pradesh, Rajasthan.

# %%
 result = result.sort_values('Transaction_Amount')
list(result.iloc[0:5,0])
# Out:
# ['Lakshadweep', 'Andaman & Nicobar Islands', 'Mizoram', 'Ladakh', 'Meghalaya']

# %%
#top 5 states with the lowest tarnsaction volumes
#' Lakshadweep, Andaman & Nicobar Islands, Ladakh, Mizoram, Meghalaya'

# %% [markdown]
# ## 2.2: Identify the most common transaction types in each state and quarter

# %%
# for each state and quarter, determine the most frequent transaction type, 
#in tabular form

# %%
sts.head()
# Out:
#                        State  Year  Quarter          Transaction Type  \
# 0  Andaman & Nicobar Islands  2018        1  Recharge & bill payments
# 1  Andaman & Nicobar Islands  2018        1     Peer-to-peer payments
# 2  Andaman & Nicobar Islands  2018        1         Merchant payments
# 3  Andaman & Nicobar Islands  2018        1        Financial Services
# 4  Andaman & Nicobar Islands  2018        1                    Others
#
#    Transactions  Amount (INR)    ATV (INR)
# 0          4200  1.845307e+06   439.358921
# 1          1871  1.213866e+07  6487.790112
# 2           298  4.525072e+05  1518.480432
# 3            33  1.060142e+04   321.255149
# 4           256  1.846899e+05   721.444790

# %%
pd.DataFrame(sts.groupby(['State','Year','Quarter'])['Transactions'].idxmax())
# Out:
#                                         Transactions
# State                     Year Quarter
# Andaman & Nicobar Islands 2018 1                   0
#                                2                   5
#                                3                  10
#                                4                  15
#                           2019 1                  20
# ...                                              ...
# West Bengal               2020 2                2489
#                                3                2494
#                                4                2499
#                           2021 1                2504
#                                2                2509
#
# [504 rows x 1 columns]

# %%
df =sts.loc[sts.groupby(['State','Year','Quarter'])['Transactions'].idxmax()].reset_index(drop=True)

# %%
df.head(10)
# Out:
#                        State  Year  Quarter          Transaction Type  \
# 0  Andaman & Nicobar Islands  2018        1  Recharge & bill payments
# 1  Andaman & Nicobar Islands  2018        2  Recharge & bill payments
# 2  Andaman & Nicobar Islands  2018        3  Recharge & bill payments
# 3  Andaman & Nicobar Islands  2018        4  Recharge & bill payments
# 4  Andaman & Nicobar Islands  2019        1  Recharge & bill payments
# 5  Andaman & Nicobar Islands  2019        2  Recharge & bill payments
# 6  Andaman & Nicobar Islands  2019        3  Recharge & bill payments
# 7  Andaman & Nicobar Islands  2019        4     Peer-to-peer payments
# 8  Andaman & Nicobar Islands  2020        1     Peer-to-peer payments
# 9  Andaman & Nicobar Islands  2020        2  Recharge & bill payments
#
#    Transactions  Amount (INR)    ATV (INR)
# 0          4200  1.845307e+06   439.358921
# 1          6735  2.320945e+06   344.609463
# 2          8636  4.343505e+06   502.953320
# ...

# %% [markdown]
# ## 2.3 Determine the device brand with highest number of registered users in each state

# %%
sdd
# Out:
#                           State  Year  Quarter    Brand  Registered Users  \
# 0     Andaman & Nicobar Islands  2018        1   Xiaomi              1665
# 1     Andaman & Nicobar Islands  2018        1  Samsung              1445
# 2     Andaman & Nicobar Islands  2018        1     Vivo               982
# 3     Andaman & Nicobar Islands  2018        1     Oppo               501
# 4     Andaman & Nicobar Islands  2018        1  OnePlus               332
# ...                         ...   ...      ...      ...               ...
# 5539                West Bengal  2021        2   Lenovo            350841
# 5540                West Bengal  2021        2     Asus            297579
# 5541                West Bengal  2021        2   Huawei            272965
# 5542                West Bengal  2021        2    Apple            201393
# 5543                West Bengal  2021        2   Others           1928653
#
#       Percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# ...

# %%
grouped = pd.DataFrame(sdd.groupby(['State','Brand'])['Registered Users'].sum())
grouped
# Out:
#                                     Registered Users
# State                     Brand
# Andaman & Nicobar Islands Apple                 9334
#                           Huawei               11497
#                           Lenovo                5362
#                           Motorola              9491
#                           OnePlus              15397
# ...                                              ...
# West Bengal               Others            17526532
#                           Realme             9322038
#                           Samsung           30516315
#                           Vivo              18755122
#                           Xiaomi            38265764
#
# [448 rows x 1 columns]

# %%
final_df = grouped.loc[grouped.groupby(['State'])['Registered Users'].idxmax()]
final_df
# Out:
#                                               Registered Users
# State                                Brand
# Andaman & Nicobar Islands            Xiaomi              97889
# Andhra Pradesh                       Xiaomi           40061549
# Arunachal Pradesh                    Xiaomi             437803
# Assam                                Xiaomi            6979357
# Bihar                                Xiaomi           33721314
# Chandigarh                           Xiaomi             896628
# Chhattisgarh                         Xiaomi            8763373
# Dadra & Nagar Haveli and Daman & Diu Xiaomi             638834
# Delhi                                Xiaomi           24114984
# Goa                                  Xiaomi            1208672
# Gujarat                              Xiaomi           28942157
# Haryana                              Xiaomi           21102142
# Himachal Pradesh                     Xiaomi            3978888
# ...

# %% [markdown]
# ## 2.4: Create a list of the top district per state based on population

# %% [markdown]
# ## 1. For each state, identify the district with the highest population. Display the results in tabular format.

# %%
df = dd.loc[dd.groupby(['State'])['Population'].idxmax()].reset_index(drop=True)

# %%
df['District(State)']= df['District'] +'( ' + df['State'] + ')' 
df
# Out:
#                                    State                District Headquarters  \
# 0              Andaman & Nicobar Islands           South Andaman   Port Blair
# 1                         Andhra Pradesh           East Godavari     Kakinada
# 2                      Arunachal Pradesh              Papum Pare        Yupia
# 3                                  Assam                  Nagaon       Nagaon
# 4                                  Bihar                   Patna        Patna
# 5                             Chandigarh              Chandigarh   Chandigarh
# 6                           Chhattisgarh                  Raipur       Raipur
# 7   Dadra & Nagar Haveli and Daman & Diu  Dadra and Nagar Haveli     Silvassa
# 8                                  Delhi        North West Delhi   Kanjhawala
# 9                                    Goa               North Goa       Panaji
# 10                               Gujarat               Ahmedabad    Ahmedabad
# ...

# %%
colm = df.pop('District(State)')

# %%
df.insert(0,'District(State)', colm)

# %%
df = df.sort_values(by='Population').reset_index(drop=True)
df
# Out:
#                                       District(State)  \
# 0                           Lakshadweep( Lakshadweep)
# 1                                     Kargil( Ladakh)
# 2                      Papum Pare( Arunachal Pradesh)
# 3           South Andaman( Andaman & Nicobar Islands)
# 4                                East Sikkim( Sikkim)
# 5   Dadra and Nagar Haveli( Dadra & Nagar Haveli a...
# 6                                    Aizawl( Mizoram)
# 7                                 Tuensang( Nagaland)
# 8                               Imphal West( Manipur)
# 9                                     North Goa( Goa)
# 10                       East Khasi Hills( Meghalaya)
# 11                             West Tripura( Tripura)
# 12                            Puducherry( Puducherry)
# 13                            Chandigarh( Chandigarh)
# 14                          Kangra( Himachal Pradesh)
# 15                            Jammu( Jammu & Kashmir)
# ...

# %%
districts = df.iloc[:,0]
population = df.iloc[:,4]

plt.plot(districts,population,marker='o')
plt.xlabel('District(State)')
plt.ylabel('Population')
plt.xticks(rotation=90)
plt.show();

# %% [markdown]
# ## 2.5 Calculate the average transaction value (ATV) for each state

# %% [markdown]
# ## 2.5.1 Compute the ATV for each state. in Tabular formate

# %%
stu
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens
# ...

# %%
df = stu.groupby(['State'])['ATV (INR)'].mean().to_frame()

# %%
df
# Out:
#                                         ATV (INR)
# State
# Andaman & Nicobar Islands             3159.266422
# Andhra Pradesh                        1748.091476
# Arunachal Pradesh                     2638.323985
# Assam                                 2008.495656
# Bihar                                 2023.316978
# Chandigarh                            2113.797075
# Chhattisgarh                          1650.818617
# Dadra & Nagar Haveli and Daman & Diu  1487.395599
# Delhi                                 1589.839307
# Goa                                   1895.258549
# Gujarat                               1696.101220
# Haryana                               1831.840325
# Himachal Pradesh                      1825.338700
# Jammu & Kashmir                       2508.506029
# Jharkhand                             1632.342997
# Karnataka                             1517.392249
# Kerala                                1671.443173
# Ladakh                                3408.222984
# ...

# %% [markdown]
# ## 2.5.2 Identify top 5 states with highest ATV and top 5 with lowest

# %%
df = df.sort_values('ATV (INR)', ascending=False).reset_index()
df
# Out:
#                                    State    ATV (INR)
# 0                                 Ladakh  3408.222984
# 1              Andaman & Nicobar Islands  3159.266422
# 2                                Mizoram  2927.517802
# 3                            Lakshadweep  2776.118701
# 4                      Arunachal Pradesh  2638.323985
# 5                                Manipur  2621.225756
# 6                               Nagaland  2609.942590
# 7                        Jammu & Kashmir  2508.506029
# 8                             Chandigarh  2113.797075
# 9                                 Sikkim  2087.843818
# 10                                Punjab  2085.225325
# 11                             Meghalaya  2056.276339
# 12                                 Bihar  2023.316978
# 13                                 Assam  2008.495656
# 14                            Puducherry  1927.611843
# 15                                   Goa  1895.258549
# ...

# %%
final_top5_high = list(df.sort_values('ATV (INR)', ascending=False).iloc[0:5,0])

final_top5_high
# Out:
# ['Ladakh',
#  'Andaman & Nicobar Islands',
#  'Mizoram',
#  'Lakshadweep',
#  'Arunachal Pradesh']

# %%
final_top5_low = list(df.sort_values('ATV (INR)').iloc[0:5,0])

final_top5_low
# Out:
# ['West Bengal',
#  'Odisha',
#  'Dadra & Nagar Haveli and Daman & Diu',
#  'Maharashtra',
#  'Karnataka']

# %% [markdown]
# ## 2.6: Analyze app usage trends

# %% [markdown]
# ''## 2.6.1. Calculate the total number of app opens over the years and quartes fpr each state. Display in tabular format.'''

# %%
df = stu.groupby(['State','Year','Quarter'])['App Opens'].sum().to_frame().reset_index()

# %%
df
# Out:
#                          State  Year  Quarter  App Opens
# 0    Andaman & Nicobar Islands  2018        1          0
# 1    Andaman & Nicobar Islands  2018        2          0
# 2    Andaman & Nicobar Islands  2018        3          0
# 3    Andaman & Nicobar Islands  2018        4          0
# 4    Andaman & Nicobar Islands  2019        1          0
# ..                         ...   ...      ...        ...
# 499                West Bengal  2020        2  198589332
# 500                West Bengal  2020        3  246554831
# 501                West Bengal  2020        4  291721919
# 502                West Bengal  2021        1  316832674
# 503                West Bengal  2021        2  275341466
#
# [504 rows x 4 columns]

# %%
df_final_UP = df.loc[df['State']== 'Uttar Pradesh'].reset_index(drop=True)

# %%
df_final_UP
# Out:
#             State  Year  Quarter  App Opens
# 0   Uttar Pradesh  2018        1          0
# 1   Uttar Pradesh  2018        2          0
# 2   Uttar Pradesh  2018        3          0
# 3   Uttar Pradesh  2018        4          0
# 4   Uttar Pradesh  2019        1          0
# 5   Uttar Pradesh  2019        2   78394040
# 6   Uttar Pradesh  2019        3  268142606
# 7   Uttar Pradesh  2019        4  324068625
# 8   Uttar Pradesh  2020        1  374282083
# 9   Uttar Pradesh  2020        2  383703534
# 10  Uttar Pradesh  2020        3  450784508
# 11  Uttar Pradesh  2020        4  552220798
# 12  Uttar Pradesh  2021        1  639718324
# 13  Uttar Pradesh  2021        2  673598864

# %%
df_final_UP['Year_Quarter']= df['Year'].astype(str) + ' Q' + df['Quarter'].astype(str)
df_final_UP
# Out:
#             State  Year  Quarter  App Opens Year_Quarter
# 0   Uttar Pradesh  2018        1          0      2018 Q1
# 1   Uttar Pradesh  2018        2          0      2018 Q2
# 2   Uttar Pradesh  2018        3          0      2018 Q3
# 3   Uttar Pradesh  2018        4          0      2018 Q4
# 4   Uttar Pradesh  2019        1          0      2019 Q1
# 5   Uttar Pradesh  2019        2   78394040      2019 Q2
# 6   Uttar Pradesh  2019        3  268142606      2019 Q3
# 7   Uttar Pradesh  2019        4  324068625      2019 Q4
# 8   Uttar Pradesh  2020        1  374282083      2020 Q1
# 9   Uttar Pradesh  2020        2  383703534      2020 Q2
# 10  Uttar Pradesh  2020        3  450784508      2020 Q3
# 11  Uttar Pradesh  2020        4  552220798      2020 Q4
# 12  Uttar Pradesh  2021        1  639718324      2021 Q1
# 13  Uttar Pradesh  2021        2  673598864      2021 Q2

# %%
plt.plot(df_final_UP['Year_Quarter'],df_final_UP['App Opens'],marker='o')
plt.xlabel('Year-Quarter')
plt.ylabel('App_Usage')
plt.title('App Usage over time for State UP')
plt.xticks(rotation=45)
plt.grid(True)
plt.show();

# %% [markdown]
# ## 2.7: Distribution of transaction types.
# Create a bar chart showing the distribution of different transaction types for each state for most recent quarter in the data sheet.

# %%
sts
# Out:
#                           State  Year  Quarter          Transaction Type  \
# 0     Andaman & Nicobar Islands  2018        1  Recharge & bill payments
# 1     Andaman & Nicobar Islands  2018        1     Peer-to-peer payments
# 2     Andaman & Nicobar Islands  2018        1         Merchant payments
# 3     Andaman & Nicobar Islands  2018        1        Financial Services
# 4     Andaman & Nicobar Islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 2509                West Bengal  2021        2     Peer-to-peer payments
# 2510                West Bengal  2021        2         Merchant payments
# 2511                West Bengal  2021        2  Recharge & bill payments
# 2512                West Bengal  2021        2        Financial Services
# 2513                West Bengal  2021        2                    Others
#
#       Transactions  Amount (INR)    ATV (INR)
# ...

# %%
sts.describe()
# Out:
#               Year      Quarter  Transactions  Amount (INR)    ATV (INR)
# count  2514.000000  2514.000000  2.514000e+03  2.514000e+03  2514.000000
# mean   2019.286794     2.358393  8.167446e+06  1.443978e+10  1349.927929
# std       1.030807     1.109251  2.423645e+07  5.995054e+10  1534.866221
# min    2018.000000     1.000000  2.000000e+00  3.439721e+01    17.198606
# 25%    2018.000000     1.000000  2.788075e+04  1.762412e+07   385.735827
# 50%    2019.000000     2.000000  2.687980e+05  1.901189e+08   720.940406
# 75%    2020.000000     3.000000  3.683230e+06  2.661248e+09  1352.790116
# max    2021.000000     4.000000  2.795990e+08  8.721520e+11  7767.539936

# %%
sts.loc[sts['Year']== 2021]['Quarter'].max()
# Out:
# 2

# %%
df = sts.loc[(sts['Year']== 2021) & (sts['Quarter']== 2)]
df
# Out:
#                           State  Year  Quarter          Transaction Type  \
# 65    Andaman & Nicobar Islands  2021        2     Peer-to-peer payments
# 66    Andaman & Nicobar Islands  2021        2  Recharge & bill payments
# 67    Andaman & Nicobar Islands  2021        2         Merchant payments
# 68    Andaman & Nicobar Islands  2021        2        Financial Services
# 69    Andaman & Nicobar Islands  2021        2                    Others
# ...                         ...   ...      ...                       ...
# 2509                West Bengal  2021        2     Peer-to-peer payments
# 2510                West Bengal  2021        2         Merchant payments
# 2511                West Bengal  2021        2  Recharge & bill payments
# 2512                West Bengal  2021        2        Financial Services
# 2513                West Bengal  2021        2                    Others
#
#       Transactions  Amount (INR)    ATV (INR)
# ...

# %%
all_states = list(df['State'].unique())

all_states
# Out:
# ['Andaman & Nicobar Islands',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Dadra & Nagar Haveli and Daman & Diu',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Ladakh',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttarakhand',
#  'Uttar Pradesh',
#  'West Bengal']

# %%
df = df.drop(['Year','Quarter','Amount (INR)','ATV (INR)'],axis=1).reset_index(drop=True)
df
# Out:
#                          State          Transaction Type  Transactions
# 0    Andaman & Nicobar Islands     Peer-to-peer payments        132772
# 1    Andaman & Nicobar Islands  Recharge & bill payments        120911
# 2    Andaman & Nicobar Islands         Merchant payments         85143
# 3    Andaman & Nicobar Islands        Financial Services           960
# 4    Andaman & Nicobar Islands                    Others          1628
# ..                         ...                       ...           ...
# 175                West Bengal     Peer-to-peer payments      64661051
# 176                West Bengal         Merchant payments      41696787
# 177                West Bengal  Recharge & bill payments      34799709
# 178                West Bengal        Financial Services        190537
# 179                West Bengal                    Others        549353
#
# [180 rows x 3 columns]

# %%
df
# Out:
#                          State          Transaction Type  Transactions
# 0    Andaman & Nicobar Islands     Peer-to-peer payments        132772
# 1    Andaman & Nicobar Islands  Recharge & bill payments        120911
# 2    Andaman & Nicobar Islands         Merchant payments         85143
# 3    Andaman & Nicobar Islands        Financial Services           960
# 4    Andaman & Nicobar Islands                    Others          1628
# ..                         ...                       ...           ...
# 175                West Bengal     Peer-to-peer payments      64661051
# 176                West Bengal         Merchant payments      41696787
# 177                West Bengal  Recharge & bill payments      34799709
# 178                West Bengal        Financial Services        190537
# 179                West Bengal                    Others        549353
#
# [180 rows x 3 columns]

# %%
pivot_data = df.pivot(index='State', columns='Transaction Type', values='Transactions')
pivot_data
# Out:
# Transaction Type                      Financial Services  Merchant payments  \
# State
# Andaman & Nicobar Islands                            960              85143
# Andhra Pradesh                                    243237          112875274
# Arunachal Pradesh                                   1582             243375
# Assam                                              49671            4562669
# Bihar                                             149791           44686786
# Chandigarh                                          5502            1926913
# Chhattisgarh                                       40213           15369311
# Dadra & Nagar Haveli and Daman & Diu                1826             802899
# Delhi                                             158170           75620295
# Goa                                                 8303            1869384
# Gujarat                                           128647           42593432
# ...

# %%
ax = pivot_data.plot(kind='bar', stacked=True, figsize=(15, 10))

# Customize the chart
plt.title(f'Distribution of Transaction Types by State for 2021 Q2')
plt.xlabel('State')
plt.ylabel('Number of Transactions')
plt.legend(title='Transaction Type', loc='upper left')
plt.plot()
# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show();

# %%
#or
plt.figure(figsize=(20, 10))
ax = sns.barplot(x='State', y='Transactions', hue='Transaction Type',data=df)

# Customize the chart
plt.title(f'Distribution of Transaction Types by State 2021 q2', fontsize=16)
plt.xlabel('State', fontsize=12)
plt.ylabel('Number of Transactions', fontsize=12)
plt.legend(title='Transaction Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adjust layout to prevent cutting off labels

plt.tight_layout()
# Show the plot
plt.show();

# %% [markdown]
# ## 2.8: Find the unique mapping between district name and district code
# 2.8.1: Idenify the unique mapping between district names and district code from the dataset.

# %%
dd
# Out:
#               State       District    Headquarters  Population  Area (sq km)  \
# 0    Andhra Pradesh      Anantapur       Anantapur     4083315       19130.0
# 1    Andhra Pradesh       Chittoor        Chittoor     4170468       15152.0
# 2    Andhra Pradesh  East Godavari        Kakinada     5151549       10807.0
# 3    Andhra Pradesh         Guntur          Guntur     4889230       11391.0
# 4    Andhra Pradesh            YSR          Kadapa     2884524       15359.0
# ..              ...            ...             ...         ...           ...
# 737           Delhi     West Delhi  Rajouri Garden     2543243         112.0
# 738      Puducherry       Karaikal        Karaikal      200222         157.0
# 739      Puducherry           Mahé            Mahé       41816           9.0
# 740      Puducherry     Puducherry     Pondicherry      950289         293.0
# 741      Puducherry          Yanam           Yanam       55626          30.0
#
#      Density  Code Alternate Name
# ...

# %%
len(dd.index)
len(dd['Code'].unique())

(dd['Code'].value_counts() >1).sum()
# Out:
# 742
# 742
# 0

# %%
len(dd['District'].unique())

dd['District'].value_counts()

(dd['District'].value_counts()>1).sum()
# Out:
# 736
# District
# Bijapur       2
# Hamirpur      2
# Aurangabad    2
# Balrampur     2
# Pratapgarh    2
#              ..
# Mandya        1
# Mysore        1
# Raichur       1
# Ramanagara    1
# Yanam         1
# Name: count, Length: 736, dtype: int64
# 6

# %%
lolo = dd.duplicated(subset='District', keep=False)
dd.loc[lolo].sort_values('District')
# Out:
#                 State    District Headquarters  Population  Area (sq km)  \
# 74              Bihar  Aurangabad   Aurangabad     2511243        3303.0
# 334       Maharashtra  Aurangabad   Aurangabad     3695928       10107.0
# 112      Chhattisgarh   Balrampur    Balrampur      730491        3806.0
# 597     Uttar Pradesh   Balrampur    Balrampur     2149066        3349.0
# 115      Chhattisgarh     Bijapur      Bijapur      229832        6562.0
# 237         Karnataka     Bijapur      Bijapur     2175102       10517.0
# 116      Chhattisgarh    Bilaspur     Bilaspur     1961922        3508.0
# 195  Himachal Pradesh    Bilaspur     Bilaspur      382056        1167.0
# 197  Himachal Pradesh    Hamirpur     Hamirpur      454293        1118.0
# 620     Uttar Pradesh    Hamirpur     Hamirpur     1104021        4325.0
# 496         Rajasthan  Pratapgarh   Pratapgarh      867848        4112.0
# 646     Uttar Pradesh  Pratapgarh   Pratapgarh     3173752        3717.0
#
# ...

# %%
df.drop_duplicates(subset='District'),inplace=True)

# %%
df['District'].value_counts()>1).sum()
# Out:
# 0

# %%
dd.info()  # containg Duplicates
print('\n')
df.info()  #not containg Duplicates
new_dd = df.copy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           742 non-null    object
#  1   District        742 non-null    object
#  2   Headquarters    742 non-null    object
#  3   Population      742 non-null    int64
#  4   Area (sq km)    742 non-null    float64
#  5   Density         742 non-null    int64
#  6   Code            742 non-null    object
#  7   Alternate Name  742 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 46.5+ KB
#
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 736 entries, 0 to 741
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           736 non-null    object
#  1   District        736 non-null    object
#  2   Headquarters    736 non-null    object
# ...

# %%
df_final = df[['District','Code']]
df_final
# Out:
#           District  Code
# 0        Anantapur  AP01
# 1         Chittoor  AP02
# 2    East Godavari  AP03
# 3           Guntur  AP04
# 4              YSR  AP13
# ..             ...   ...
# 737     West Delhi  DL11
# 738       Karaikal  PY01
# 739           Mahé  PY02
# 740     Puducherry  PY03
# 741          Yanam  PY04
#
# [736 rows x 2 columns]

# %%
df_final.to_csv('Map_District_with_Code', index=False)

# %%
pd.read_csv('Map_District_with_Code')
# Out:
#           District  Code
# 0        Anantapur  AP01
# 1         Chittoor  AP02
# 2    East Godavari  AP03
# 3           Guntur  AP04
# 4              YSR  AP13
# ..             ...   ...
# 731     West Delhi  DL11
# 732       Karaikal  PY01
# 733           Mahé  PY02
# 734     Puducherry  PY03
# 735          Yanam  PY04
#
# [736 rows x 2 columns]

# %%
############ Task 3#########################
'''Data Quality Checks'''

# %% [markdown]
# ## 3.1: Ensure data consistency across state and district levels

# %% [markdown]
# ## 3.1.1. For each state, calculate the total number of transactions, total transaction AMOUNT, and total registered users by summing up the values from district level data.

# %%
dtu.head()
# Out:
#                        State  Year  Quarter                  District  Code  \
# 0  Andaman & Nicobar Islands  2018        1                  Nicobars  AN01
# 1  Andaman & Nicobar Islands  2018        1  North And Middle Andaman  AN02
# 2  Andaman & Nicobar Islands  2018        1             South Andaman  AN03
# 3  Andaman & Nicobar Islands  2018        2                  Nicobars  AN01
# 4  Andaman & Nicobar Islands  2018        2  North And Middle Andaman  AN02
#
#    Transactions  Amount (INR)    ATV (INR)  Registered Users  App Opens
# 0           528  1.139849e+06  2158.804548               262          0
# 1           442  9.316631e+05  2107.835016               632          0
# 2          5688  1.256025e+07  2208.201361              5846          0
# 3          1120  3.072437e+06  2743.247239               351          0
# 4           825  1.317863e+06  1597.409798               911          0

# %%
dist_data = dtu.groupby(['State'])[['Transactions','Amount (INR)','Registered Users']].sum()
dist_data
# Out:
#                                       Transactions  Amount (INR)  \
# State
# Andaman & Nicobar Islands                  1223565  3.641818e+09
# Andhra Pradesh                          1781091169  3.860292e+12
# Arunachal Pradesh                          8043799  2.225183e+10
# Assam                                    123577981  2.814087e+11
# Bihar                                    713643889  1.639579e+12
# Chandigarh                                25516542  5.371208e+10
# Chhattisgarh                             241908549  4.156353e+11
# Dadra & Nagar Haveli and Daman & Diu      12462185  1.865878e+10
# Delhi                                   1011031124  1.649942e+12
# Goa                                       24481604  4.427187e+10
# Gujarat                                  612992823  1.105329e+12
# Haryana                                  567751410  1.059832e+12
# Himachal Pradesh                          52987445  9.786546e+10
# ...

# %%
state_data = stu.groupby(['State'])[['Transactions','Amount (INR)','Registered Users']].sum()
state_data
# Out:
#                                       Transactions  Amount (INR)  \
# State
# Andaman & Nicobar Islands                  1223565  3.641818e+09
# Andhra Pradesh                          1781091169  3.187847e+12
# Arunachal Pradesh                          8043799  2.225183e+10
# Assam                                    123577981  2.814087e+11
# Bihar                                    713643889  1.639579e+12
# Chandigarh                                25516542  5.371208e+10
# Chhattisgarh                             241908549  4.156353e+11
# Dadra & Nagar Haveli and Daman & Diu      12462185  1.865878e+10
# Delhi                                   1011031124  1.649942e+12
# Goa                                       24481604  4.427187e+10
# Gujarat                                  612992823  1.105329e+12
# Haryana                                  567751410  1.059832e+12
# Himachal Pradesh                          52987445  9.786546e+10
# ...

# %%
state_data['Amount (INR)'] = state_data['Amount (INR)'].round(0)
dist_data['Amount (INR)'] = dist_data['Amount (INR)'].round(0)

# %%
state_data.loc['Rajasthan']
# Out:
# Transactions        1.382919e+09
# Amount (INR)        2.625584e+12
# Registered Users    1.497701e+08
# Name: Rajasthan, dtype: float64

# %%
state_data.loc['Rajasthan']- dist_data.loc['Rajasthan']
# Out:
# Transactions        0.0
# Amount (INR)        0.0
# Registered Users    0.0
# Name: Rajasthan, dtype: float64

# %%
comparision = state_data == dist_data
discrepancy = ~comparision
discrepancy
# Out:
#                                       Transactions  Amount (INR)  \
# State
# Andaman & Nicobar Islands                    False         False
# Andhra Pradesh                               False          True
# Arunachal Pradesh                            False         False
# Assam                                        False         False
# Bihar                                        False         False
# Chandigarh                                   False         False
# Chhattisgarh                                 False         False
# Dadra & Nagar Haveli and Daman & Diu         False         False
# Delhi                                        False         False
# Goa                                          False         False
# Gujarat                                      False         False
# Haryana                                      False         False
# Himachal Pradesh                             False         False
# ...

# %%
state_data.loc[discrepancy['Amount (INR)']]
dist_data.loc[discrepancy['Amount (INR)']]
#so, there are discrepancies
# Out:
#                 Transactions  Amount (INR)  Registered Users
# State
# Andhra Pradesh    1781091169  3.187847e+12         158007957
#                 Transactions  Amount (INR)  Registered Users
# State
# Andhra Pradesh    1781091169  3.860292e+12         158007957

# %%
# so, the discrepancies are found in Amount(INR) column for state-wise and district wise transaction amount data.

#The state where discrepancies are found is Andhra Pradesh.

# %%
############TASK 4############################

# %% [markdown]
# ## TASK 4: Data merging and Advance Analysis.
#
# ## 4.1: Ratio of users to population by state.
# Merge the State_Txn and Users dataset with the District Demographics dataset to calculate the ratio of registered users to the population for each state. Display results in tabular form

# %%
state_updated = stu[(stu['Year']== 2021) & (stu['Quarter']==2)]
state_updated
# Out:
#                                     State  Year  Quarter  Transactions  \
# 13              Andaman & Nicobar Islands  2021        2        341414
# 27                         Andhra Pradesh  2021        2     352767134
# 41                      Arunachal Pradesh  2021        2       1568338
# 55                                  Assam  2021        2      25432905
# 69                                  Bihar  2021        2     155603622
# 83                             Chandigarh  2021        2       4417547
# 97                           Chhattisgarh  2021        2      44689420
# 111  Dadra & Nagar Haveli and Daman & Diu  2021        2       2125083
# 125                                 Delhi  2021        2     170157264
# 139                                   Goa  2021        2       4710135
# 153                               Gujarat  2021        2     111841396
# 167                               Haryana  2021        2     105680856
# ...

# %%
state_data = state_updated[['State', 'Registered Users']].reset_index(drop=True)
state_data
# Out:
#                                    State  Registered Users
# 0              Andaman & Nicobar Islands             62095
# 1                         Andhra Pradesh          19620905
# 2                      Arunachal Pradesh            270572
# 3                                  Assam           3617056
# 4                                  Bihar          14972134
# 5                             Chandigarh            448572
# 6                           Chhattisgarh           4837055
# 7   Dadra & Nagar Haveli and Daman & Diu            344994
# 8                                  Delhi          11182699
# 9                                    Goa            609106
# 10                               Gujarat          15735981
# 11                               Haryana          10530594
# 12                      Himachal Pradesh           1743151
# 13                       Jammu & Kashmir           1261267
# 14                             Jharkhand           5701503
# ...

# %%
state_data
# Out:
#                                    State  Registered Users
# 0              Andaman & Nicobar Islands             62095
# 1                         Andhra Pradesh          19620905
# 2                      Arunachal Pradesh            270572
# 3                                  Assam           3617056
# 4                                  Bihar          14972134
# 5                             Chandigarh            448572
# 6                           Chhattisgarh           4837055
# 7   Dadra & Nagar Haveli and Daman & Diu            344994
# 8                                  Delhi          11182699
# 9                                    Goa            609106
# 10                               Gujarat          15735981
# 11                               Haryana          10530594
# 12                      Himachal Pradesh           1743151
# 13                       Jammu & Kashmir           1261267
# 14                             Jharkhand           5701503
# ...

# %%
pop_data= new_dd.groupby('State')['Population'].sum().to_frame().reset_index()

# %%
pop_data
# Out:
#                                    State  Population
# 0              Andaman & Nicobar Islands      380581
# 1                         Andhra Pradesh    49378776
# 2                      Arunachal Pradesh     1606047
# 3                                  Assam    34461385
# 4                                  Bihar   103817951
# 5                             Chandigarh     1055450
# 6                           Chhattisgarh    25867958
# 7   Dadra & Nagar Haveli and Daman & Diu      586956
# 8                                  Delhi    16787941
# 9                                    Goa     1457723
# 10                               Gujarat    65930328
# 11                               Haryana    25855357
# 12                      Himachal Pradesh     6474453
# 13                       Jammu & Kashmir    12258093
# 14                             Jharkhand    32966238
# 15                             Karnataka    58790858
# 16                                Kerala    33387677
# ...

# %%
df_final = pd.merge(left= state_data, right=pop_data, on='State', how='inner')

# %%
df_final
# Out:
#                                    State  Registered Users  Population
# 0              Andaman & Nicobar Islands             62095      380581
# 1                         Andhra Pradesh          19620905    49378776
# 2                      Arunachal Pradesh            270572     1606047
# 3                                  Assam           3617056    34461385
# 4                                  Bihar          14972134   103817951
# 5                             Chandigarh            448572     1055450
# 6                           Chhattisgarh           4837055    25867958
# 7   Dadra & Nagar Haveli and Daman & Diu            344994      586956
# 8                                  Delhi          11182699    16787941
# 9                                    Goa            609106     1457723
# 10                               Gujarat          15735981    65930328
# 11                               Haryana          10530594    25855357
# ...

# %%
df_final['users/population'] = df_final['Registered Users']/df_final['Population']
df_final
# Out:
#                                    State  Registered Users  Population  \
# 0              Andaman & Nicobar Islands             62095      380581
# 1                         Andhra Pradesh          19620905    49378776
# 2                      Arunachal Pradesh            270572     1606047
# 3                                  Assam           3617056    34461385
# 4                                  Bihar          14972134   103817951
# 5                             Chandigarh            448572     1055450
# 6                           Chhattisgarh           4837055    25867958
# 7   Dadra & Nagar Haveli and Daman & Diu            344994      586956
# 8                                  Delhi          11182699    16787941
# 9                                    Goa            609106     1457723
# 10                               Gujarat          15735981    65930328
# 11                               Haryana          10530594    25855357
# ...

# %%
#2. Create a column cg=hart for users and population

# %%
plt.xlabel('State')
plt.ylabel('Ratio of registered users to Population')
plt.xticks(rotation=90)
plt.title('The ratio of Registered users to population by state')
plt.scatter(df_final['State'], df_final['users/population'])
plt.show();

# %% [markdown]
# ## 4.2. Correlate population density with transaction volume

# %%
#1. Merge the District_Txn and Users dataset with the District Demographics data.

# %%
# here we need to work only for year 2021 and Q2 (latest data)

# %%
dist_data = dtu[(dtu['Year']== 2021) & (dtu['Quarter']==2)].reset_index(drop=True)
dist_data
# Out:
#                          State  Year  Quarter                    District  \
# 0    Andaman & Nicobar Islands  2021        2                    Nicobars
# 1    Andaman & Nicobar Islands  2021        2    North And Middle Andaman
# 2    Andaman & Nicobar Islands  2021        2               South Andaman
# 3               Andhra Pradesh  2021        2                   Anantapur
# 4               Andhra Pradesh  2021        2                    Chittoor
# ..                         ...   ...      ...                         ...
# 727                West Bengal  2021        2             Purba Bardhaman
# 728                West Bengal  2021        2             Purba Medinipur
# 729                West Bengal  2021        2                     Purulia
# 730                West Bengal  2021        2  South Twenty Four Parganas
# 731                West Bengal  2021        2              Uttar Dinajpur
#
#      Code  Transactions  Amount (INR)    ATV (INR)  Registered Users  \
# ...

# %%
# (as per task 2.8) we defined new_dd contained cleaned data of district demographic (dd), removed duplicated of district names.
new_dd['District'].value_counts()
# Out:
# District
# Anantapur    1
# Rajsamand    1
# Jodhpur      1
# Jaipur       1
# Jaisalmer    1
#             ..
# Kodagu       1
# Kolar        1
# Koppal       1
# Mandya       1
# Yanam        1
# Name: count, Length: 736, dtype: int64

# %%
df_final = pd.merge(left=dist_data, right=new_dd, on=['State','District','Code'])
df_final
# Out:
#                          State  Year  Quarter           District  Code  \
# 0    Andaman & Nicobar Islands  2021        2      South Andaman  AN03
# 1               Andhra Pradesh  2021        2          Anantapur  AP01
# 2               Andhra Pradesh  2021        2           Chittoor  AP02
# 3               Andhra Pradesh  2021        2      East Godavari  AP03
# 4               Andhra Pradesh  2021        2             Guntur  AP04
# ..                         ...   ...      ...                ...   ...
# 618                West Bengal  2021        2  Paschim Medinipur  WB18
# 619                West Bengal  2021        2    Purba Bardhaman  WB19
# 620                West Bengal  2021        2    Purba Medinipur  WB20
# 621                West Bengal  2021        2            Purulia  WB21
# 622                West Bengal  2021        2     Uttar Dinajpur  WB23
#
#      Transactions  Amount (INR)    ATV (INR)  Registered Users  App Opens  \
# ...

# %%
#4.2.2. Calculate the correlation between population density and transaction volume.
#4.2.3. create a scatter plot

# %%
df_final=df_final.sort_values(by='Density').reset_index(drop=True)
df_final
# Out:
#                  State  Year  Quarter          District  Code  Transactions  \
# 0              Manipur  2021        2          Kakching  MN07         37444
# 1    Arunachal Pradesh  2021        2         Lepa Rada  AR08         21273
# 2    Arunachal Pradesh  2021        2       Lower Siang  AR12         17401
# 3              Manipur  2021        2        Tengnoupal  MN14         23771
# 4                Delhi  2021        2  South East Delhi  DL09      11519378
# ..                 ...   ...      ...               ...   ...           ...
# 618              Delhi  2021        2         New Delhi  DL03      36788618
# 619         Chandigarh  2021        2        Chandigarh  CH01       4417547
# 620         Tamil Nadu  2021        2           Chennai  TN03      43737916
# 621          Telangana  2021        2         Hyderabad  TG03     212326623
# 622        West Bengal  2021        2           Kolkata  WB12      41726247
#
# ...

# %%
correlation = df_final['Amount (INR)'].corr(df_final['Density'])
correlation

#correlation between population density and transaction volumne is 0.45378946858252395

# so, higher density areas might be associated with higher transaction volumes, although other factors also considered
# Out:
# 0.45378946858252395

# %%
plt.xlabel('Density')
plt.ylabel('Amount (INR)')
plt.xticks(rotation=90)
plt.title('The correlation between population density and transaction volume')
plt.scatter(df_final['Density'], df_final['Amount (INR)'])
plt.show();

# %% [markdown]
# ## 4.3: Average transaction amount per user.
# 1. Merge relevant datasets to calculate the average transaction amount per user for each state. Display results in a tabular formate.
# 2. Identify top5 states with highest average transaction amount per user and the top5 states with lowest average amount per user. Display results.

# %%
# Again, we have to take latest data set i.e. 2021 and q2.

df_final = stu[(stu['Year']==2021) & (stu['Quarter']==2)].reset_index(drop=True)
df_final
# Out:
#                                    State  Year  Quarter  Transactions  \
# 0              Andaman & Nicobar Islands  2021        2        341414
# 1                         Andhra Pradesh  2021        2     352767134
# 2                      Arunachal Pradesh  2021        2       1568338
# 3                                  Assam  2021        2      25432905
# 4                                  Bihar  2021        2     155603622
# 5                             Chandigarh  2021        2       4417547
# 6                           Chhattisgarh  2021        2      44689420
# 7   Dadra & Nagar Haveli and Daman & Diu  2021        2       2125083
# 8                                  Delhi  2021        2     170157264
# 9                                    Goa  2021        2       4710135
# 10                               Gujarat  2021        2     111841396
# 11                               Haryana  2021        2     105680856
# ...

# %%
df_final['ATV per User'] = df_final['ATV (INR)']/df_final['Registered Users']
df_final = df_final.sort_values(by='ATV per User',ascending=False).reset_index(drop=True)
df_final
# Out:
#                                    State  Year  Quarter  Transactions  \
# 0                            Lakshadweep  2021        2         11384
# 1                                 Ladakh  2021        2        399716
# 2              Andaman & Nicobar Islands  2021        2        341414
# 3                                Mizoram  2021        2        394340
# 4                                 Sikkim  2021        2        976714
# 5                               Nagaland  2021        2       1130791
# 6                              Meghalaya  2021        2        909594
# 7                      Arunachal Pradesh  2021        2       1568338
# 8                                Manipur  2021        2       3086275
# 9                             Puducherry  2021        2       3751387
# 10  Dadra & Nagar Haveli and Daman & Diu  2021        2       2125083
# 11                            Chandigarh  2021        2       4417547
# ...

# %%
Top_5_high = list(df_final.iloc[0:6,0])
Top_5_high
# Out:
# ['Lakshadweep',
#  'Ladakh',
#  'Andaman & Nicobar Islands',
#  'Mizoram',
#  'Sikkim',
#  'Nagaland']

# %%
Top_5_low = list(df_final.iloc[31:36,0])
Top_5_low
# Out:
# ['Rajasthan', 'Tamil Nadu', 'Uttar Pradesh', 'Karnataka', 'Maharashtra']

# %%
stu
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens
# ...

# %% [markdown]
# ## 4.4: Device brand usage ratio
# 1. Merge state_deviceData with satet_Txn and users dataset.
# 2. Calculate ratio of users using each device brand to total number of registered users in each state. display results in tabular format.
# 3. Create a bar depicting the device brand usage ratio for each state.

# %%
latest_sdd = sdd[(sdd['Year']==2021) & (sdd['Quarter']==2)].reset_index(drop=True)
latest_sdd
# Out:
#                          State  Year  Quarter    Brand  Registered Users  \
# 0    Andaman & Nicobar Islands  2021        2     Vivo             15056
# 1    Andaman & Nicobar Islands  2021        2   Xiaomi             14788
# 2    Andaman & Nicobar Islands  2021        2  Samsung             11476
# 3    Andaman & Nicobar Islands  2021        2     Oppo              5456
# 4    Andaman & Nicobar Islands  2021        2   Realme              4034
# ..                         ...   ...      ...      ...               ...
# 391                West Bengal  2021        2   Lenovo            350841
# 392                West Bengal  2021        2     Asus            297579
# 393                West Bengal  2021        2   Huawei            272965
# 394                West Bengal  2021        2    Apple            201393
# 395                West Bengal  2021        2   Others           1928653
#
#      Percentage
# 0      0.242467
# 1      0.238151
# 2      0.184814
# 3      0.087865
# ...

# %%
latest_stu = stu[(stu['Year']==2021) & (stu['Quarter']==2)].reset_index(drop=True)
latest_stu= latest_stu.rename(columns={'Registered Users':'Registered Users in state'})
latest_stu
# Out:
#                                    State  Year  Quarter  Transactions  \
# 0              Andaman & Nicobar Islands  2021        2        341414
# 1                         Andhra Pradesh  2021        2     352767134
# 2                      Arunachal Pradesh  2021        2       1568338
# 3                                  Assam  2021        2      25432905
# 4                                  Bihar  2021        2     155603622
# 5                             Chandigarh  2021        2       4417547
# 6                           Chhattisgarh  2021        2      44689420
# 7   Dadra & Nagar Haveli and Daman & Diu  2021        2       2125083
# 8                                  Delhi  2021        2     170157264
# 9                                    Goa  2021        2       4710135
# 10                               Gujarat  2021        2     111841396
# 11                               Haryana  2021        2     105680856
# ...

# %%
df_final = pd.merge(left=latest_stu, right=latest_sdd, on=['State','Year','Quarter'], how='left')
df_final
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2021        2        341414  8.991470e+08
# 1    Andaman & Nicobar Islands  2021        2        341414  8.991470e+08
# 2    Andaman & Nicobar Islands  2021        2        341414  8.991470e+08
# 3    Andaman & Nicobar Islands  2021        2        341414  8.991470e+08
# 4    Andaman & Nicobar Islands  2021        2        341414  8.991470e+08
# ..                         ...   ...      ...           ...           ...
# 391                West Bengal  2021        2     141897437  2.794348e+11
# 392                West Bengal  2021        2     141897437  2.794348e+11
# 393                West Bengal  2021        2     141897437  2.794348e+11
# 394                West Bengal  2021        2     141897437  2.794348e+11
# 395                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users in state  App Opens    Brand  \
# ...

# %%
df_final['Brand users per total users']= df_final['Registered Users']/df_final['Registered Users in state']
df_final
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2021        2        341414  8.991470e+08
# 1    Andaman & Nicobar Islands  2021        2        341414  8.991470e+08
# 2    Andaman & Nicobar Islands  2021        2        341414  8.991470e+08
# 3    Andaman & Nicobar Islands  2021        2        341414  8.991470e+08
# 4    Andaman & Nicobar Islands  2021        2        341414  8.991470e+08
# ..                         ...   ...      ...           ...           ...
# 391                West Bengal  2021        2     141897437  2.794348e+11
# 392                West Bengal  2021        2     141897437  2.794348e+11
# 393                West Bengal  2021        2     141897437  2.794348e+11
# 394                West Bengal  2021        2     141897437  2.794348e+11
# 395                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users in state  App Opens    Brand  \
# ...

# %%
 '''/*for state in df_final['State'].unique():
    lolo = df_final['State'] == state
    state_data = df_final[lolo]
    df_final.plot.bar(state_data['Brand'],state_data['Brand users per total users'], label=state)
    
plt.xlabel('Brand')
plt.ylabel('Ratio of Brand Users to Total State Users')
plt.title('Device Brand Usage Ratio for Each State')
plt.legend(title='State')
plt.show();'''

# %%
states = df_final['State'].unique()

# Plotting the bar graph
fig, ax = plt.subplots(figsize=(10, 16))

# Loop through states and plot for each state
for idx, state in enumerate(states):
    state_data = df_final[df_final['State'] == state]
    ax.bar(state_data['Brand'], state_data['Brand users per total users'], label=state)

# Adding labels and title
ax.set_xlabel('Brand')
ax.set_ylabel('Ratio of Brand Users to Total State Users')
ax.set_title('Device Brand Usage Ratio for Each State')
ax.tick_params(rotation=90)
ax.legend(title='State')
plt.tight_layout()
plt.show();

# %%
############################TASK 5##############################################

# %% [markdown]
# ## TASK 5: Data Visualization

# %% [markdown]
# ## 5.1: Create a line plot showing total number of transactions and the total transaction amount over time (for any state)

# %%
# lets take state 'Uttar Pradesh' for the analysis

df = stu.copy()
df = df[df['State'] == 'Uttar Pradesh']
df['Year_Quarter'] = df['Year'].astype('str') + ' Q'+ df['Quarter'].astype('str')
df.drop(columns=['Year','Quarter'],inplace=True)
df
# Out:
#              State  Transactions  Amount (INR)    ATV (INR)  Registered Users  \
# 476  Uttar Pradesh      12537805  1.393997e+10  1111.835040           4694250
# 477  Uttar Pradesh      17710943  2.572020e+10  1452.220906           6442554
# 478  Uttar Pradesh      26515356  3.701211e+10  1395.874691           8096483
# 479  Uttar Pradesh      36100767  5.509674e+10  1526.193158          10341964
# 480  Uttar Pradesh      57324504  7.652418e+10  1334.929651          12458661
# 481  Uttar Pradesh      58883500  9.891752e+10  1679.885186          14316349
# 482  Uttar Pradesh      68623959  1.112681e+11  1621.418220          16044607
# 483  Uttar Pradesh      86905005  1.455389e+11  1674.689812          17949542
# 484  Uttar Pradesh      97239132  1.724164e+11  1773.117791          20136256
# 485  Uttar Pradesh     100851965  1.787440e+11  1772.340441          22498519
# 486  Uttar Pradesh     127405259  2.486900e+11  1951.959891          24838116
# ...

# %%
plt.plot(df['Year_Quarter'], df['Transactions'], label='No of Transactions')
plt.xlabel('Year_Quarter')
plt.ylabel('Transactions')
plt.xticks(rotation=45)
plt.legend()
plt.show();

# %%
plt.plot(df['Year_Quarter'], df['Amount (INR)'], label='Transaction Amount(INR)')
plt.xlabel('Year_Quarter')
plt.ylabel('Transactions Amount(INR)')
plt.xticks(rotation=45)
plt.legend()
plt.show();

# %% [markdown]
# ## 5.2: Create a pie chart showing the distribution of transaction types for a specific quarter

# %%
sts
# Out:
#                           State  Year  Quarter          Transaction Type  \
# 0     Andaman & Nicobar Islands  2018        1  Recharge & bill payments
# 1     Andaman & Nicobar Islands  2018        1     Peer-to-peer payments
# 2     Andaman & Nicobar Islands  2018        1         Merchant payments
# 3     Andaman & Nicobar Islands  2018        1        Financial Services
# 4     Andaman & Nicobar Islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 2509                West Bengal  2021        2     Peer-to-peer payments
# 2510                West Bengal  2021        2         Merchant payments
# 2511                West Bengal  2021        2  Recharge & bill payments
# 2512                West Bengal  2021        2        Financial Services
# 2513                West Bengal  2021        2                    Others
#
#       Transactions  Amount (INR)    ATV (INR)
# ...

# %%
# lets take state 'Uttar Pradesh' for the analysis

df = sts.copy()
df = df[(df['State'] == 'Uttar Pradesh') & (df['Year'] == 2021) & (df['Quarter']== 2)]
df
# Out:
#               State  Year  Quarter          Transaction Type  Transactions  \
# 2439  Uttar Pradesh  2021        2     Peer-to-peer payments     102927942
# 2440  Uttar Pradesh  2021        2         Merchant payments      84860582
# 2441  Uttar Pradesh  2021        2  Recharge & bill payments      53030710
# 2442  Uttar Pradesh  2021        2        Financial Services        270944
# 2443  Uttar Pradesh  2021        2                    Others        858953
#
#       Amount (INR)    ATV (INR)
# 2439  3.887618e+11  3777.028983
# 2440  7.035140e+10   829.023317
# 2441  2.226693e+10   419.887404
# 2442  2.668531e+08   984.901186
# 2443  5.254877e+08   611.776992

# %%
sizes = list(df['Transactions']/total_transactions)
labels= list(df['Transaction Type'])
explode = [0.1,0,0,0,0]
plt.pie(sizes,explode = explode,labels=labels, shadow=True, autopct='%1.1f%%',pctdistance=1.1)
plt.show();

# %%
import plotly.express as px

fig = px.pie(df, values=list(df['Transactions']/total_transactions), names=df['Transaction Type'])
fig.show()
# Out:
# <div>                            <div id="90dcc5be-9367-4b0b-b879-9f228bc0c405" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90dcc5be-9367-4b0b-b879-9f228bc0c405")) {                    Plotly.newPlot(                        "90dcc5be-9367-4b0b-b879-9f228bc0c405",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Transaction Type=%{label}<br>value=%{value}<extra></extra>","labels":["Peer-to-peer payments","Merchant payments","Recharge & bill payments","Financial Services","Others"],"legendgroup":"","name":"","showlegend":true,"values":[0.42541149693155955,0.35073728783096975,0.21918123772885137,0.001119838698656041,0.0035501388099633225],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour
# ...

# %% [markdown]
# ## 5.3. Create a bar plot showing the population density of districts in a selected state

# %%
df= new_dd.copy()
df = df[df['State']=='Uttar Pradesh'].reset_index(drop=True)
df
# Out:
#             State        District Headquarters  Population  Area (sq km)  \
# 0   Uttar Pradesh            Agra         Agra     4380793        4027.0
# 1   Uttar Pradesh         Aligarh      Aligarh     3673849        3747.0
# 2   Uttar Pradesh       Allahabad    Allahabad     5959798        5481.0
# 3   Uttar Pradesh  Ambedkar Nagar     Akbarpur     2398709        2372.0
# 4   Uttar Pradesh          Amethi    Gauriganj     2549935        3063.0
# ..            ...             ...          ...         ...           ...
# 67  Uttar Pradesh         Sitapur      Sitapur     4474446        5743.0
# 68  Uttar Pradesh       Sonbhadra  Robertsganj     1862612        6788.0
# 69  Uttar Pradesh       Sultanpur    Sultanpur     3790922        4436.0
# 70  Uttar Pradesh           Unnao        Unnao     3110595        4561.0
# 71  Uttar Pradesh        Varanasi     Varanasi     3682194        1535.0
#
#     Density  Code  Alternate Name
# 0      1084  UP01            Agra
# ...

# %%
plt.figure(figsize=(14, 8))
plt.xlabel('Districts of Uttar Pradesh(UP)')
plt.ylabel('Population Density')
plt.title('Distric wise poppulation Density of Uttar Pradesh(UP)')
plt.bar(df['District'],df['Density'], color='g',edgecolor='k')
plt.xticks(rotation=90, ha='right', fontsize=10)
plt.tight_layout()
plt.show();

# %%
###################################TASK 6#######################################

# %% [markdown]
# ## TASK 6: Insights and Conclusions [Advance Section]

# %% [markdown]
# ## 6.1: Identify any trends or patterns in the transaction data
# Analyse the transaction data to identify any noticeable trends or patterns. Summarize your findings. hint- create a line graph at year or quarter and discuss your findings.

# %%
stu
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens
# ...

# %%
result = stu.groupby(['Year','Quarter']).agg(
    No_of_Transactions=('Transactions', 'sum'),
    Transaction_Amount=('Amount (INR)', 'sum')
).reset_index()

value = df['Year'].astype(str) +' Q' +df['Quarter'].astype(str)
result.insert(0, 'Year_quarter', value)
result.drop(columns=['Year','Quarter'], inplace=True)
result
# Out:
#    Year_quarter  No_of_Transactions  Transaction_Amount
# 0       2018 Q1           134425599        1.718334e+11
# 1       2018 Q2           187365440        3.043742e+11
# 2       2018 Q3           341299764        4.751015e+11
# 3       2018 Q4           417111607        6.717362e+11
# 4       2019 Q1           708992981        9.900214e+11
# 5       2019 Q2           815380896        1.354214e+12
# 6       2019 Q3          1095009675        1.672559e+12
# 7       2019 Q4          1460443663        2.259894e+12
# 8       2020 Q1          1623038046        2.697112e+12
# 9       2020 Q2          1448608890        2.646145e+12
# 10      2020 Q3          2033051183        3.902053e+12
# 11      2020 Q4          2869276622        5.395851e+12
# 12      2021 Q1          3457585463        5.611799e+12
# 13      2021 Q2          3941370465        7.476466e+12

# %%
plt.xlabel('Time')
plt.ylabel('No of transactions')
plt.title('Transaction Count Trends: Analysis of Financial Activities from 2018 to 2021 ')
plt.plot(result['Year_quarter'],result['No_of_Transactions'])
plt.xticks(rotation=45)
plt.tight_layout()
plt.show();

# %% [markdown]
# From the above grapgh it seems like the no. of transactions increases over time, however during 2020 Q2, there is slight decrease but from next quarter onwads it took a higher growth rate.

# %%
plt.xlabel('Time')
plt.ylabel('Transaction_Amount')
plt.title('Transaction Amount Trends: Analysis of Financial Activities from 2018 to 2021 ')
plt.plot(result['Year_quarter'],result['Transaction_Amount'])
plt.xticks(rotation=45)
plt.tight_layout()
plt.show();

# %% [markdown]
# From the above graph, we can see same trends of gowth in Transaction Amount but here in year 2020 Q1 to Q2 the amount remained almost same but later it shows higher rate of growth

# %% [markdown]
# ## 6.2: Correlate demographics data with transaction data.
# FInd correlations between demographic data (eg. density) and transaction data (eg. volume). summarize the findings

# %%
stu.head(5)
new_dd.head(5)
# Out:
#                        State  Year  Quarter  Transactions  Amount (INR)  \
# 0  Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1  Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2  Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3  Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4  Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
#
#      ATV (INR)  Registered Users  App Opens
# 0  2197.621091              6740          0
# 1  2498.989022              9405          0
# 2  3415.768284             12149          0
# 3  3811.277720             15222          0
# 4  3355.630147             18596          0
#             State       District Headquarters  Population  Area (sq km)  \
# 0  Andhra Pradesh      Anantapur    Anantapur     4083315       19130.0
# 1  Andhra Pradesh       Chittoor     Chittoor     4170468       15152.0
# ...

# %%
'''Lets take latest data 2021 q2'''

df1 = stu.copy()
df1 = df1[(df1['Year'] == 2021) & (df1['Quarter']== 2)].reset_index(drop=True)
df1.drop(columns=['Year','Quarter'], inplace=True)
df1
# Out:
# 'Lets take latest data 2021 q2'
#                                    State  Transactions  Amount (INR)  \
# 0              Andaman & Nicobar Islands        341414  8.991470e+08
# 1                         Andhra Pradesh     352767134  8.507375e+11
# 2                      Arunachal Pradesh       1568338  4.456426e+09
# 3                                  Assam      25432905  5.919247e+10
# 4                                  Bihar     155603622  3.745803e+11
# 5                             Chandigarh       4417547  8.417674e+09
# 6                           Chhattisgarh      44689420  7.872877e+10
# 7   Dadra & Nagar Haveli and Daman & Diu       2125083  3.157668e+09
# 8                                  Delhi     170157264  2.819411e+11
# 9                                    Goa       4710135  8.012854e+09
# 10                               Gujarat     111841396  2.101621e+11
# 11                               Haryana     105680856  2.003574e+11
# ...

# %%
df2 = new_dd.groupby('State')['Density'].mean().to_frame().reset_index()
df2
# Out:
#                                    State       Density
# 0              Andaman & Nicobar Islands     45.666667
# 1                         Andhra Pradesh    341.769231
# 2                      Arunachal Pradesh     24.320000
# 3                                  Assam    462.264706
# 4                                  Bihar   1142.736842
# 5                             Chandigarh   9258.000000
# 6                           Chhattisgarh    232.107143
# 7   Dadra & Nagar Haveli and Daman & Diu   1803.000000
# 8                                  Delhi  13995.818182
# 9                                    Goa    398.500000
# 10                               Gujarat    372.181818
# 11                               Haryana    676.818182
# 12                      Himachal Pradesh    188.090909
# 13                       Jammu & Kashmir    416.250000
# 14                             Jharkhand    460.666667
# 15                             Karnataka    424.500000
# ...

# %%
final = pd.merge(left= df1,right=df2, on = 'State').sort_values(by='Density')
final
# Out:
#                                    State  Transactions  Amount (INR)  \
# 17                                Ladakh        399716  1.427259e+09
# 2                      Arunachal Pradesh       1568338  4.456426e+09
# 23                               Mizoram        394340  1.122874e+09
# 0              Andaman & Nicobar Islands        341414  8.991470e+08
# 24                              Nagaland       1130791  3.156294e+09
# 22                             Meghalaya        909594  2.193617e+09
# 29                                Sikkim        976714  2.424900e+09
# 12                      Himachal Pradesh       9483902  1.649563e+10
# 21                               Manipur       3086275  7.889828e+09
# 6                           Chhattisgarh      44689420  7.872877e+10
# 19                        Madhya Pradesh     223314680  4.255008e+11
# 33                           Uttarakhand      24000432  4.099082e+10
# 28                             Rajasthan     287477039  5.617028e+11
# ...

# %%
plt.xlabel('Population density')
plt.ylabel('Transaction Volumne')
plt.title('Analysis of transaction volume as per Population Density')
plt.plot(final['Density'],final['Amount (INR)'])
plt.tight_layout()
plt.show();

# %%
final['Density'].corr(final['Amount (INR)'])

'''Very Weak Correlation:
The correlation coefficient is extremely close to zero (0.0038), indicating an extremely weak positive correlation between Density and Amount (INR).'''
# Out:
# 0.0037872669728738354
# 'Very Weak Correlation:\nThe correlation coefficient is extremely close to zero (0.0038), indicating an extremely weak positive correlation between Density and Amount (INR).'

# %% [markdown]
# We will analyse Transaction volumne based on population

# %%
'''Lets take latest data 2021 q2'''

df1 = stu.copy()
df1 = df1[(df1['Year'] == 2021) & (df1['Quarter']== 2)].reset_index(drop=True)
df1.drop(columns=['Year','Quarter'], inplace=True)
df1
# Out:
# 'Lets take latest data 2021 q2'
#                                    State  Transactions  Amount (INR)  \
# 0              Andaman & Nicobar Islands        341414  8.991470e+08
# 1                         Andhra Pradesh     352767134  8.507375e+11
# 2                      Arunachal Pradesh       1568338  4.456426e+09
# 3                                  Assam      25432905  5.919247e+10
# 4                                  Bihar     155603622  3.745803e+11
# 5                             Chandigarh       4417547  8.417674e+09
# 6                           Chhattisgarh      44689420  7.872877e+10
# 7   Dadra & Nagar Haveli and Daman & Diu       2125083  3.157668e+09
# 8                                  Delhi     170157264  2.819411e+11
# 9                                    Goa       4710135  8.012854e+09
# 10                               Gujarat     111841396  2.101621e+11
# 11                               Haryana     105680856  2.003574e+11
# ...

# %%
df2 = new_dd.groupby('State')['Population'].sum().to_frame().reset_index()
df2
# Out:
#                                    State  Population
# 0              Andaman & Nicobar Islands      380581
# 1                         Andhra Pradesh    49378776
# 2                      Arunachal Pradesh     1606047
# 3                                  Assam    34461385
# 4                                  Bihar   103817951
# 5                             Chandigarh     1055450
# 6                           Chhattisgarh    25867958
# 7   Dadra & Nagar Haveli and Daman & Diu      586956
# 8                                  Delhi    16787941
# 9                                    Goa     1457723
# 10                               Gujarat    65930328
# 11                               Haryana    25855357
# 12                      Himachal Pradesh     6474453
# 13                       Jammu & Kashmir    12258093
# 14                             Jharkhand    32966238
# 15                             Karnataka    58790858
# 16                                Kerala    33387677
# ...

# %%
final = pd.merge(left= df1,right=df2, on = 'State').sort_values(by='Population').reset_index(drop=True)
final
# Out:
#                                    State  Transactions  Amount (INR)  \
# 0                            Lakshadweep         11384  2.738346e+07
# 1                                 Ladakh        399716  1.427259e+09
# 2              Andaman & Nicobar Islands        341414  8.991470e+08
# 3   Dadra & Nagar Haveli and Daman & Diu       2125083  3.157668e+09
# 4                                 Sikkim        976714  2.424900e+09
# 5                             Chandigarh       4417547  8.417674e+09
# 6                                Mizoram        394340  1.122874e+09
# 7                             Puducherry       3751387  6.498835e+09
# 8                                    Goa       4710135  8.012854e+09
# 9                      Arunachal Pradesh       1568338  4.456426e+09
# 10                              Nagaland       1130791  3.156294e+09
# 11                               Manipur       3086275  7.889828e+09
# 12                             Meghalaya        909594  2.193617e+09
# ...

# %%
plt.xlabel('Population')
plt.ylabel('Transaction Volumne')
plt.title('Analysis of transaction volume as per Population Density')
plt.plot(final['Population'],final['Amount (INR)'])
plt.tight_layout()
plt.show();

# %%
final['Population'].corr(final['Amount (INR)']) 

'''In summary, there's a substantial positive relationship between Population and Amount (INR) in your dataset. This suggests that population size could be a useful factor to consider when analyzing or predicting transaction amounts,'''
# Out:
# 0.6118872948545224
# "In summary, there's a substantial positive relationship between Population and Amount (INR) in your dataset. This suggests that population size could be a useful factor to consider when analyzing or predicting transaction amounts,"

# %% [markdown]
# ## 6.3: Summarize findings and insights

# %%
# Out:
# 0.8662019576950696

# %%
stu
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens
# ...

# %%
# Correlation betwn Registered Users App Opens

stu['Registered Users'].corr(stu['App Opens'])

'''SO, there is a decent correlation between them'''
# Out:
# 0.8662019576950696
# 'SO, there is a decent correlation between them'

# %% [markdown]
# ## Trend Analysis for state wise ATV for latest year and Quarter

# %%
dtu
# Out:
#                            State  Year  Quarter                    District  \
# 0      Andaman & Nicobar Islands  2018        1                    Nicobars
# 1      Andaman & Nicobar Islands  2018        1    North And Middle Andaman
# 2      Andaman & Nicobar Islands  2018        1               South Andaman
# 3      Andaman & Nicobar Islands  2018        2                    Nicobars
# 4      Andaman & Nicobar Islands  2018        2    North And Middle Andaman
# ...                          ...   ...      ...                         ...
# 10243                West Bengal  2021        2             Purba Bardhaman
# 10244                West Bengal  2021        2             Purba Medinipur
# 10245                West Bengal  2021        2                     Purulia
# 10246                West Bengal  2021        2  South Twenty Four Parganas
# 10247                West Bengal  2021        2              Uttar Dinajpur
#
# ...

# %%
df = dtu[(dtu['Year']==2021) & (dtu['Quarter']==2)]
df
# Out:
#                            State  Year  Quarter                    District  \
# 39     Andaman & Nicobar Islands  2021        2                    Nicobars
# 40     Andaman & Nicobar Islands  2021        2    North And Middle Andaman
# 41     Andaman & Nicobar Islands  2021        2               South Andaman
# 211               Andhra Pradesh  2021        2                   Anantapur
# 212               Andhra Pradesh  2021        2                    Chittoor
# ...                          ...   ...      ...                         ...
# 10243                West Bengal  2021        2             Purba Bardhaman
# 10244                West Bengal  2021        2             Purba Medinipur
# 10245                West Bengal  2021        2                     Purulia
# 10246                West Bengal  2021        2  South Twenty Four Parganas
# 10247                West Bengal  2021        2              Uttar Dinajpur
#
# ...

# %%
final_df = dtu.groupby(['State'])['ATV (INR)'].mean().to_frame().reset_index().sort_values(by='ATV (INR)')
final_df
# Out:
#                                    State    ATV (INR)
# 35                           West Bengal  1377.639842
# 32                               Tripura  1548.465799
# 8                                  Delhi  1569.462534
# 20                           Maharashtra  1589.759225
# 25                                Odisha  1593.026649
# 10                               Gujarat  1615.279858
# 7   Dadra & Nagar Haveli and Daman & Diu  1627.099576
# 16                                Kerala  1663.601305
# 34                           Uttarakhand  1692.261103
# 19                        Madhya Pradesh  1712.902405
# 22                             Meghalaya  1747.020228
# 6                           Chhattisgarh  1763.384439
# 33                         Uttar Pradesh  1773.513881
# 15                             Karnataka  1814.371859
# 12                      Himachal Pradesh  1835.931747
# 3                                  Assam  1839.568384
# ...

# %%
plt.xlabel('Sates')
plt.ylabel('Average Transaction Amount in INR')
plt.tittle("")
plt.plot(final_df['State'],final_df['ATV (INR)'])
plt.xticks(rotation=90)
plt.tight_layout()
plt.show();

# %%
'''So, the TOP states for Highest ATV Value are'''
list(final_df.sort_values(by='ATV (INR)',ascending=False).iloc[0:6,0])
# Out:
# 'So, the TOP states for Highest ATV Value are'
# ['Ladakh',
#  'Andaman & Nicobar Islands',
#  'Mizoram',
#  'Lakshadweep',
#  'Arunachal Pradesh',
#  'Manipur']
